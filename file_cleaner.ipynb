# %% [markdown]
# # File Cleaner for ._ and .DS Files

# %%
# Import the utility function
from utils import clean_directory

# %%
# Set target directory
target_directory = r"C:\Users\wanglab\Desktop\Tip_Tracker"

# %%
# To actually delete the files:
print("=== ACTUAL DELETION ===")
result = clean_directory(target_directory, dry_run=False)
print(f"Final result: {result}")
# Out:
# Scanning directory: C:\Users\wanglab\Desktop\Tip_Tracker
# Looking for files with prefixes: ['.DS', '._']
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\.DS_Store
# Looking for files with prefixes: ['.DS', '._']
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\.DS_Store
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\._.DS_Store
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\._data_config.json
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\._.DS_Store
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\._data_config.json
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\images\._0000001.png
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\images\._0001488.png
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\images\._0001493.png
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\images\._0000001.png
# Deleted: C:\Users\wanglab\Desktop\Tip_Tracker\10_bottom\images\._0001488.png
# ...
